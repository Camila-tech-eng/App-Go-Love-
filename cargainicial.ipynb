# %%
import pandas as pd
import sqlite3
from transformers import pipeline

# %%
df = pd.read_csv(r'C:\Users\camis\apps\dados\cargainicial.csv')
df
# Out:
#                                            Pergunta\n
# 0   Qual característica da minha personalidade voc...
# 1   Qual característica da minha personalidade voc...
# 2   Quando percebeu que estava apaixonado(a) por mim?
# 3       Quais planos você ainda quer realizar comigo?
# 4   Como você se sente quando está com minha família?
# ..                                                ...
# 95                           No que você mais tem fé?
# 96   Quais foram suas primeiras impressões sobre mim?
# 97                               O que te faz chorar?
# 98  Se eu precisasse mudar de cidade, você iria co...
# 99        Como seria sua festa de casamento perfeita?
#
# [100 rows x 1 columns]

# %%
conn = sqlite3.connect("golove.db")
cursor = conn.cursor()

# %%
analisador = pipeline("sentiment-analysis",
                      model="nlptown/bert-base-multilingual-uncased-sentiment")
# Out:
# Device set to use cpu

# %%
def classificar_nivel(texto):
    resultado = analisador(texto[:512])[0]
    label = resultado["label"]
    if "1 star" in label or "2 stars" in label:
        return "Vermelho (profundo/emocional)"
    elif "3 stars" in label:
        return "Amarelo (moderado/reflexivo)"
    else:
        return "Verde (leve/divertido)"

# %%
df = pd.read_csv(r'C:\Users\camis\apps\dados\cargainicial.csv')

# %%
df.columns = df.columns.str.strip().str.replace('\n', '', regex=True)
print("✅ Colunas encontradas:", list(df.columns))
col_texto = "Pergunta" if "Pergunta" in df.columns else df.columns[0]
# Out:
# ✅ Colunas encontradas: ['Pergunta']

# %%
conn = sqlite3.connect(r"C:\Users\camis\apps\dados\golove.db")
cursor = conn.cursor()

# %%
import sqlite3

conn = sqlite3.connect(r"C:\Users\camis\apps\dados\golove.db")
cursor = conn.cursor()

cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
print(cursor.fetchall())
# Out:
# []

# %%
conn.commit()
conn.close()

print(" Inserção concluída com sucesso!")
# Out:
#  Inserção concluída com sucesso!
